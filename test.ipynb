# %%
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
from langchain_openai import ChatOpenAI

# %%
llm = ChatOpenAI(model="gpt-4o-mini")

# %%
llm.invoke("What is GenAI ?")
# Out:
# AIMessage(content='GenAI, short for Generative Artificial Intelligence, refers to a class of AI technologies that can generate new content, data, or information based on patterns learned from existing datasets. This content can vary widely, encompassing text, images, music, code, and more.\n\nKey characteristics of GenAI include:\n\n1. **Generative Models**: GenAI leverages models such as Generative Adversarial Networks (GANs), Variational Autoencoders (VAEs), and transformer-based architectures (like GPT models) to create new content.\n\n2. **Applications**: The technology is used in various domains, including but not limited to:\n   - Text generation (e.g., chatbots, story writing)\n   - Image and video synthesis (e.g., deepfakes, art creation)\n   - Music and audio generation\n   - Code completion or generation\n\n3. **Interactive Tools**: GenAI can provide interactive services that allow users to influence or direct the content generation process, making it a versatile tool for creative work.\n\n4. **Research and Development**: The field is a hotbed of research, with ongoing work to improve the quality, reliability, and ethical considerations of generated content.\n\n5. **Personalization**: GenAI can be used to create personalized experiences, adapting outputs based on user preferences and inputs.\n\nAs GenAI continues to evolve, it raises important questions about authenticity, copyright, and ethical use, prompting ongoing discussions in the tech community and beyond.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 297, 'prompt_tokens': 12, 'total_tokens': 309, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_373a14eb6f', 'id': 'chatcmpl-D9CCrMybiSXMbMc2H302nAOPVyaSD', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c5cd9-410b-77d2-b1dd-4cafab4dcc1d-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 12, 'output_tokens': 297, 'total_tokens': 309, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})
